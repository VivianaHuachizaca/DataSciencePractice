# %% [markdown]
# Clase virtual

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/data/anscombe.csv')

# %%
df1 = df[df['dataset']== 'I']
df2 = df[df['dataset']== 'II']
df3 = df[df['dataset']== 'III']
df4 = df[df['dataset']== 'IV']

# %%
df1.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031568
# min     4.000000   4.260000
# 25%     6.500000   6.315000
# 50%     9.000000   7.580000
# 75%    11.500000   8.570000
# max    14.000000  10.840000

# %%
df2.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.031657
# min     4.000000   3.100000
# 25%     6.500000   6.695000
# 50%     9.000000   8.140000
# 75%    11.500000   8.950000
# max    14.000000   9.260000

# %%
df3.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500000
# std     3.316625   2.030424
# min     4.000000   5.390000
# 25%     6.500000   6.250000
# 50%     9.000000   7.110000
# 75%    11.500000   7.980000
# max    14.000000  12.740000

# %%
df4.describe()
# Out:
#                x          y
# count  11.000000  11.000000
# mean    9.000000   7.500909
# std     3.316625   2.030579
# min     8.000000   5.250000
# 25%     8.000000   6.170000
# 50%     8.000000   7.040000
# 75%     8.000000   8.190000
# max    19.000000  12.500000

# %%
df.groupby('dataset').describe()
# Out:
#             x                                               y            \
#         count mean       std  min  25%  50%   75%   max count      mean
# dataset
# I        11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# II       11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# III      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# IV       11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#               std   min    25%   50%   75%    max
# dataset
# I        2.031568  4.26  6.315  7.58  8.57  10.84
# II       2.031657  3.10  6.695  8.14  8.95   9.26
# III      2.030424  5.39  6.250  7.11  7.98  12.74
# IV       2.030579  5.25  6.170  7.04  8.19  12.50

# %%
sns.scatterplot(data=df1, x='x', y='y', hue='dataset')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
sns.scatterplot(data=df2, x='x', y='y', hue='dataset')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
sns.scatterplot(data=df3, x='x', y='y', hue='dataset')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
sns.scatterplot(data=df4, x='x', y='y', hue='dataset')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# Análisis exploratorio utilizando visualización

# %%
tips = sns.load_dataset('tips')
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %% [markdown]
# **Análisis univariados**
#
# -No nos fijamos en las relaciones sino en una sola variable.

# %%
tips.total_bill.describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %%
sns.displot(data=tips, x = 'total_bill')

# %%
sns.boxplot(data=tips, x = 'total_bill')
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# **Análisis bivariado **

# %%
tips.groupby('day').total_bill.mean()
# Out:
# <ipython-input-25-abf1791272c7>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby('day').total_bill.mean()
# day
# Thur    17.682742
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Name: total_bill, dtype: float64

# %%
sns.boxplot(data=tips, x = 'day', y='total_bill')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips, x = 'day', y='total_bill', hue = 'smoker')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
